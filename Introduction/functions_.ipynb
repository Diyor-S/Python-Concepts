# %% [markdown]
# There is one more `Exception` that we need to talk about: `AttributeError`.
#
# This one is truly important when working with `classes`. But we are going to delay this one.
#
# Today, we are gonna talk about the **functions**.
#
# What is a `function`?
#
# First of all it is an `Object`.
# It has all the same things like: **identity**, **type**, and the **value**.
#
# Second of all, it is **conceptually** different from easily grasped Objects like `int`, `str`.
#
# Before we continue let's see what the function looks like:

# %%
# This is the basic form of the 'function'. 
# We can already see that it has 'special syntax'.
def func1():
    return 1

func1()
# Out:
# 1

# %% [markdown]
# In the above example, there are two **stages**: `Function **Definition**`, and `Function **Invocation**`.
#
# You may ask how did you know what **keyword** is used to define a function?
# Besides the overall internet videos, articles, the most reliable way to discover this information is via **official documentation**.
# Because there are things that we can find out there.
#
# https://docs.python.org/3/reference/compound_stmts.html#function-definitions
#
#
# ```python
# funcdef:                   [decorators] "def" funcname [type_params] "(" [parameter_list] ")"
#                            ["->" expression] ":" suite
# ```
#
# This explain what keyword can be used, there are parentheses ( and ) that we can use that are `REQUIRED`.
# "" - `REQUIRED`
# [] - `OPTIONAL`
# paramter_list - wrapped with [] so it is optional, meaning function can have 0 args with () usage is mandatory.
# suite - function body where we write what the function would do when it gets **invoked**.
#
# So now, let's see the function's: identity, type, and value in practice:

# %%
# Function Definition 
def func2(): 
    # Function Body
    return "This is function 2"

func2 # Function is an Object so its "value" is: <function __main__.func2()> - the reference to the function Object itself.
# Out:
# <function __main__.func2()>

# %%
id(func2) # Function Object's identity: 128737892376768
# Out:
# 128737892376768

# %%
type(func2) # Function Object's type: function
# Out:
# function

# %% [markdown]
# We are gonna explore functions more, but that is it for today (Sep 12 2026).

# %% [markdown]
# # (Sep 13 2026)
#
# ### Functions, series 2/?.

# %% [markdown]
# We have explored the first stage of the functions: `Function Definition`.
# It includes: using a `keyword - def`, giving a `name (identifier)` to the `function Object`,
# and using `parentheses` with optionally `paramter list`, and using `:` semi-colon to end `function's **signature**`.
#
# So basically everything until `:` semi-colon is considered to be `Function Signature`.
#
# Then, follows the `Function's **Body**`.
# This where we write down what the `function object` will **execute** when it gets `invoked`.

# %% [markdown]
# Function definition would not be `any useful` if there was `no second stage`: `Function Invocation` stage.
#
# What is `Invocation`?
# It means **calling** the **function Object**: using operator `()` on the function **name (identifier)**.
#
# `Function Body` - is only **executed** when the function gets **invoked**.
#
# Let's consider a full example:

# %%
# Function Definition Stage: 
# using 'def', giving a function 'name (identifier) = func1', using '()' and ':' to end 'Function Signature'
def func1():
    # 4-space identation
    # Function Body:
    print("This is the function 1")

    return 100 # Function invocation result.""

# %% [markdown]
# Now having finished Function Definition, it is up to developer - US,
# when, and where, and what we want to do with this function.

# %%
# Function Invocation:
func1() # using given 'name' together with the () - call operator.

# Look at the output, we have got Function's Body executed and it returned 100 as well.
# Out:
# This is the function 1
# 100

# %% [markdown]
# So why is there `()` - operator to invoke the function?
# Because without the parentheses we use function as plain Object,
# meaning we use it just like any other Object that we have seen such as: numbers, strings, lists etc.
#
# What conclusion can we make from this?
#
# Functions have two natures: **Object** nature, and **Behavioral** one.
#
# Whenever we use the `name` itself without `()` operator, we are working with function's **Object** nature,
# on the contrary, when we use `name` together with `()` operator, we are dealing with function's **Behavioral** nature.
#
# There are more things related to functions that I would like to talk, but this is it for today. ( Sep 13 2026 )

# %% [markdown]
# # (Sep 14 2026)
#
# Today, I would like to elaborate on take: functions have dual nature: `Object`, and `Behavioral`.
#
# But we would focus on `Object` nature of the function.
#
# Let's recall what the Object was: abstraction for some **data** whose crucial components are: `identity`, `type`, and `value`.
#
# All the other **Objects** like: 5, "string1", [1, 2, 3], (100, ), {1: "one"} possesed all of those 3 components.
#
# `Functions` are `Objects` too, so they are `NO` exception to the rule:

# %%
# Function Definition
def func1(): # Function Signature ends
    # Function Body
    return 1000


print("Function's identity: ", id(func1))
print("Function's type: ", type(func1))
print("Function's value: ", func1)
# Out:
# Function's identity:  135726258942848
# Function's type:  <class 'function'>
# Function's value:  <function func1 at 0x7b713b737380>

# %% [markdown]
# Now are gonna talk about Function's `Object` nature: being a **First-Class-Citizen** **(Citizen <-> Object)**.
#
# What is even a `First-Class-Object`?
#
# Now we need to recall everything we have been doing so far:

# %%
a = 5 # Creating a 'variable' -> "name" that references the Object of type int with value 5.
# So we are saving this to the variable in simple terms!

# %%
def func2(a):
    print(a)

# We may pass that variable into function when we 'invoke' the function object like this:
func2(a) # We are passing our variable with value 5!
# Out:
# 5

# %%
def func3(a):
    # We can return that Object from a function!
    return a

func3(a) # We have received it.
# Out:
# 5

# %%
# We have saved the result of the function invocation = function's body execution, and return value into the variable
this_is_5 = func3(a)

this_is_5 # now we are printing it out
# Out:
# 5

# %%
def func4():
    # Creating `dynamically`.
    a = 10

    return a

func4()
# Out:
# 10

# %% [markdown]
# Going back to the `First-Class-Object`.
#
# `First-Class-Object` - is an Object that:
# 1. can be **saved** into the **variable**,
# 2. **passed** to the function/class as an **argument**,
# 3. can be **returned** from the **function**.
# 4. can be **created** **dynamically** from some **function** (example)
# ...
#
# Have all the `privileges` just like any other Object.
#
# In Python - `all` **Objects** are `First-Class-Objects`. Therefore, all the points above are valid for any one of them.

# %% [markdown]
# # (Sep 15 2026)
#
# So far, we have covered two **natures** of functions: `Object` and `Behavioral` as well as
# two **stages**: `Function Definition` and `Function Invocation`.
#
# During Function Definition, to be more specific in `Function Signature` part, we define `parameter_list` of the functions.
#
# The whole purpose of functions flexibility is in their parameter_list modification.
# `WE` define what **parameters** function would be using to produce some `RESULT` that is `EXPECTED` to be `USEFUL` to `US`.

# %%
# Function that adds two numbers
def adder_func1(n1, n2):
    return n1 + n2

# %%
adder_func1() # When we invoke the function, we pass not parameters, but arguments. 
# There is a difference, but let put it away for now.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 adder_func1() # When we invoke the function, we pass not parameters, but arguments.
#       2 # There is a difference, but let put it away for now.
#
# TypeError: adder_func1() missing 2 required positional arguments: 'n1' and 'n2'

# %%
# Oops, we got the TypeError Exception. So what did we do with the `type`` of the function object wrong that we got TypeError?

adder_func1(1) # Okay, we pass it one number, and we still got TypeError.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Oops, we got the TypeError Exception. So what did we do with the `type`` of the function object wrong that we got TypeError?
#       2
# ----> 3 adder_func1(1) # Okay, we pass it one number
#
# TypeError: adder_func1() missing 1 required positional argument: 'n2'

# %%
adder_func1(5, '') # We still got TypeError, but not because of the "paramters", 
# but because given inputs have wrong types to perform that operation.

# What we get from this is there is a "NEED FOR VALIDATING" the input.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 adder_func1(5, '')
#
# Cell In[2], line 3, in adder_func1(n1, n2)
#       2 def adder_func1(n1, n2):
# ----> 3     return n1 + n2
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# Note: Whenever we missed to pass the `required arguments`, we got them marked as `positional`.
#
# This is important, because it directly says to us that `position` in which you pass the `arguments`
# **MUST** `exactly match` the `paramter list` that has been defined during `function definition`.

# %%
adder_func1(2, 4) # Now we pass some correct data, and we get what we wanted.
# Out:
# 6

# %% [markdown]
# The same issues would persist accross the other functions as well, given that we repeate the same experiment procedure.

# %%
# Function that subtracts two numbers
def subtract_func2(n1, n2): # Two positional arguments
    return n1 - n2

# %%
# Function that repeats the addition operation n times over the number num. 
def repeat_addition(num, n=1): # Now here we have, 1 positional argument
    for _ in range(n):
        num += 1

    return num

# %%
repeat_addition(5, 5)
# Out:
# 10

# %% [markdown]
# So we could see that `parameter_list` becomes `argument_list` when invoking the function, but that is not the main thing for now.
#
# For now, the main thing is that TypeError Exception that we were getting when we tried to `pass` some invalid `arguments`.
#
# To conclude,
# there are `positional` arguments and and there are also `keyword` arguments, there are also `params` with `default values`.
